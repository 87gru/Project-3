# %%
import pandas as pd

# %%
crimes_df = pd.read_csv('Output/NPYD_Complaints_01-01-13_12-31-23_v2.csv')

# %%
crimes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280576 entries, 0 to 1280575
# Data columns (total 7 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Complaint_No  1280576 non-null  object
#  1   Reported_Dt   1280576 non-null  object
#  2   Borough_Name  1280576 non-null  object
#  3   Ofns_Desc     1280576 non-null  object
#  4   Law_Cat       1280576 non-null  object
#  5   Latitude      1280576 non-null  float64
#  6   Longitude     1280576 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 68.4+ MB

# %%
# Update `Reported_Dt` to datetime
crimes_df['Reported_Dt'] = pd.to_datetime(crimes_df['Reported_Dt'])

# Sort DataFrame by the `Reported_Dt`
crimes_df = crimes_df.sort_values(by='Reported_Dt', ignore_index= True)

# Preview DataFrame
crimes_df.head(20)
# Out:
#    Complaint_No Reported_Dt Borough_Name                       Ofns_Desc  \
# 0      88397298  2013-01-01    MANHATTAN        VEHICLE AND TRAFFIC LAWS
# 1      88378509  2013-01-01    MANHATTAN    ASSAULT 3 & RELATED OFFENSES
# 2      88378508  2013-01-01    MANHATTAN  INTOXICATED & IMPAIRED DRIVING
# 3      88378506  2013-01-01    MANHATTAN    ASSAULT 3 & RELATED OFFENSES
# 4      88378505  2013-01-01    MANHATTAN                   PETIT LARCENY
# 5      88397294  2013-01-01    MANHATTAN    ASSAULT 3 & RELATED OFFENSES
# 6      88397297  2013-01-01    MANHATTAN    ASSAULT 3 & RELATED OFFENSES
# 7      88397307  2013-01-01    MANHATTAN        VEHICLE AND TRAFFIC LAWS
# 8      88400523  2013-01-01    MANHATTAN  OFFENSES AGAINST PUBLIC ADMINI
# 9      88378511  2013-01-01    MANHATTAN                   PETIT LARCENY
# 10     88378492  2013-01-01    MANHATTAN                   GRAND LARCENY
# 11     88378488  2013-01-01    MANHATTAN                   PETIT LARCENY
# ...
